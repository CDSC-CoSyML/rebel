# %%
import jax.numpy as np
from rebel_class import rebel
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import jax.numpy as np
# ----> 2 from rebel_class import rebel
#
# File ~/Forschung/git/git_public_rebel/rebel_class.py:8
#       5 from itertools import combinations_with_replacement, chain
#       6 from scipy.stats import wasserstein_distance
# ----> 8 from diffrax import diffeqsolve, ODETerm, Dopri5, SaveAt
#       9 from sympy2jax import SymbolicModule
#      11 from ott.geometry import pointcloud
#
# File ~/.local/lib/python3.10/site-packages/diffrax/__init__.py:3
#       1 import importlib.metadata
# ----> 3 from ._adjoint import (
#       4     AbstractAdjoint as AbstractAdjoint,
#       5     BacksolveAdjoint as BacksolveAdjoint,
#       6     DirectAdjoint as DirectAdjoint,
#       7     ForwardMode as ForwardMode,
#       8     ImplicitAdjoint as ImplicitAdjoint,
#       9     RecursiveCheckpointAdjoint as RecursiveCheckpointAdjoint,
#      10 )
#      11 from ._autocitation import citation as citation, citation_rules as citation_rules
#      12 from ._brownian import (
#      13     AbstractBrownianPath as AbstractBrownianPath,
#      14     UnsafeBrownianPath as UnsafeBrownianPath,
#      15     VirtualBrownianTree as VirtualBrownianTree,
#      16 )
#
# File ~/.local/lib/python3.10/site-packages/diffrax/_adjoint.py:7
#       4 from collections.abc import Callable, Iterable
#       5 from typing import Any, cast, Optional, Union
# ----> 7 import equinox as eqx
#       8 import equinox.internal as eqxi
#       9 import jax
#
# File ~/.local/lib/python3.10/site-packages/equinox/__init__.py:3
#       1 import importlib.metadata
# ----> 3 from . import debug as debug, internal as internal, nn as nn
#       4 from ._ad import (
#       5     filter_checkpoint as filter_checkpoint,
#       6     filter_closure_convert as filter_closure_convert,
#    (...)
#      15     filter_vjp as filter_vjp,
#      16 )
#      17 from ._better_abstract import (
#      18     AbstractClassVar as AbstractClassVar,
#      19     AbstractVar as AbstractVar,
#      20 )
#
# File ~/.local/lib/python3.10/site-packages/equinox/internal/__init__.py:13
#      10 from .._doc_utils import doc_remove_args as doc_remove_args, doc_repr as doc_repr
#      12 # Backward compatibility: expose via `equinox.internal`. Now available under `equinox`.
# ---> 13 from .._enum import Enumeration as Enumeration
#      15 # Backward compatibility: expose via `equinox.internal`. Now available under `equinox`.
#      16 from .._errors import (
#      17     assert_dce as assert_dce,
#      18     branched_error_if as branched_error_if,
#      19     error_if as error_if,
#      20 )
#
# File ~/.local/lib/python3.10/site-packages/equinox/_enum.py:142
#     138     def __instancecheck__(cls, value):
#     139         return isinstance(value, EnumerationItem) and value._enumeration is cls
# --> 142 class EnumerationItem(Module):
#     143     _value: Int[Array | np.ndarray[Any, np.dtype[np.signedinteger]], ""]
#     144     # Should have annotation `"type[Enumeration]"`, but this fails due to beartype bug
#     145     # #289.
#
# File ~/.local/lib/python3.10/site-packages/equinox/_enum.py:143, in EnumerationItem()
#     142 class EnumerationItem(Module):
# --> 143     _value: Int[Array | np.ndarray[Any, np.dtype[np.signedinteger]], ""]
#     144     # Should have annotation `"type[Enumeration]"`, but this fails due to beartype bug
#     145     # #289.
#     146     _enumeration: Any = field(static=True)
#
# File ~/.local/lib/python3.10/site-packages/jaxtyping/_array_types.py:578, in _MetaAbstractDtype.__getitem__(***failed resolving arguments***)
#     576 del item
#     577 if typing.get_origin(array_type) in _union_types:
# --> 578     out = [
#     579         _make_array(x, dim_str, cls.dtypes, cls.__name__)
#     580         for x in typing.get_args(array_type)
#     581     ]
#     582     out = tuple(x for x in out if x is not _not_made)
#     583     if len(out) == 0:
#
# File ~/.local/lib/python3.10/site-packages/jaxtyping/_array_types.py:579, in <listcomp>(.0)
#     576 del item
#     577 if typing.get_origin(array_type) in _union_types:
#     578     out = [
# --> 579         _make_array(x, dim_str, cls.dtypes, cls.__name__)
#     580         for x in typing.get_args(array_type)
#     581     ]
#     582     out = tuple(x for x in out if x is not _not_made)
#     583     if len(out) == 0:
#
# File ~/.local/lib/python3.10/site-packages/jaxtyping/_array_types.py:540, in _make_array(array_type, dim_str, dtypes, name)
#     538 else:
#     539     raise ValueError(f"array_name_format {_array_name_format} not recognised")
# --> 540 metaclass = _make_metaclass(type(array_type))
#     541 out = metaclass(
#     542     name,
#     543     (array_type, AbstractArray),
#    (...)
#     550     ),
#     551 )
#     552 if getattr(typing, "GENERATING_DOCUMENTATION", False):
#
# File ~/.local/lib/python3.10/site-packages/jaxtyping/_array_types.py:286, in _make_metaclass(base_metaclass)
#     284 @ft.lru_cache(maxsize=None)
#     285 def _make_metaclass(base_metaclass):
# --> 286     class MetaAbstractArray(_MetaAbstractArray, base_metaclass):
#     287         pass
#     289     return MetaAbstractArray
#
# TypeError: multiple bases have instance lay-out conflict

# %% [markdown]
# General use

# %%
data = np.load("/data/cylin3dpod.npy")
print(data.shape) # data should have the shape (N_x,N_t)

# Instantiate the rebel class with the data.
# Adjust stepsize and evals if needed for faster testing.
model = rebel(data=data, stepsize=0.01, evals=200, error="L2", order=2)

# Preprocess the data (calculate derivative and set up the library)
model.preprocess()

# (Optional) Calculate norms prior to optimization if you wish to inspect them separately.
model.calc_norms()

# Run the optimization procedure to estimate model parameters.
optimum, losses, errors = model.optimize()

# Print the optimization results.
print("Optimization optimum:", optimum)
print("Losses during optimization:", losses)
print("Errors:", errors)

# Plot the comparison of estimated vs. original trajectories.
model.plot_comparison()
# Out:
# (3, 500)
# calculating derivative with splines
# Set up rhs-library
# norms 90.03622 45096.92
# norms 90.03622 45096.92
# working with L2 error
# searching for optimal lambda
# ->working with Bayesian Information Criterion
# 100%|██████████| 200/200 [05:17<00:00,  1.59s/trial, best loss: -337.52646291083164]
# ->Best value observed at:
# lambda0= 0.6011419866301471 ,
# lambda1= 0.014041532480472834 ,
# lambda2= 0.008399349474919476 ,
# alpha =  0.9999926963137477
# (3, 500) (10, 3) (10, 500)
# ->number of parameters: p= 19
# ->saving parameters and estimated attractor
# -19.799*x_0 + 19.803*x_1
# -0.086*x_0**2 + 0.086*x_0*x_1 - 1.953*x_0*x_2 + 54.331*x_0 - 0.022*x_1**2 - 1.7*x_1 + 0.021*x_2**2 - 0.754*x_2 + 6.146
# 0.136*x_0**2 + 1.822*x_0*x_1 - 0.03*x_0 + 0.049*x_1**2 - 0.015*x_1 - 0.01*x_2**2 - 5.185*x_2 + 0.947
# rms_ls: 2.2067045001169228
# rms_int: 0.0044652945
# rms_wasserstein: -0.036831733
592942, 66.39958297456178, 230.49534981692705, 248.7478629367941, 255.48404343031837, 240.16061431342297, 129.51581567592942, -48.33502984547036, 114.98108766578628, -16.492212218241463, 250.23696577721768, 250.2368763702505, 120.63940317915313, 48.90086703069531, 178.1740665818382, 177.89786060894403, -48.33502984547036, 83.4002817240918, 83.400340397414, 253.45698123420152, 284.70320065598037, 178.17412059854752, 14.05867585501187, 83.400340397414, 178.174176477902, 253.45694398129854, 146.74146124681943]
# Errors: [2.2067045001169228, Array(0.00446529, dtype=float32), Array(-0.03683173, dtype=float32)]
# plotting comparison to ./plot.pdf

# %% [markdown]
# Use of different metrics:
#
# Wasserstein

# %%
data = np.load("/data/cylin3dpod.npy")
print(data.shape) # data should have the shape (N_x,N_t)

# Instantiate the rebel class with the data.
# Adjust stepsize and evals if needed for faster testing.
model = rebel(data=data, stepsize=0.01, evals=200, error="W", order=2)

# Preprocess the data (calculate derivative and set up the library)
model.preprocess()

# (Optional) Calculate norms prior to optimization if you wish to inspect them separately.
model.calc_norms()

# Run the optimization procedure to estimate model parameters.
optimum, losses, errors = model.optimize()

# Print the optimization results.
print("Optimization optimum:", optimum)
print("Losses during optimization:", losses)
print("Errors:", errors)

# Plot the comparison of estimated vs. original trajectories.
model.plot_comparison()
# Out:
# (3, 500)
# calculating derivative with splines
# Set up rhs-library
# /home/timk/.local/lib/python3.8/site-packages/equinox/compile_utils.py:12: FutureWarning: jax.tree_flatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_flatten instead.
#   static_leaves, static_treedef = jax.tree_flatten(static)
# /home/timk/.local/lib/python3.8/site-packages/equinox/compile_utils.py:18: FutureWarning: jax.tree_unflatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_unflatten instead.
#   static = jax.tree_unflatten(static_treedef, static_leaves)
# /home/timk/.local/lib/python3.8/site-packages/equinox/tree.py:119: FutureWarning: jax.tree_flatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_flatten instead.
#   leaves1, structure1 = jax.tree_flatten(node_or_nodes_nowrapper, is_leaf=is_leaf)
# /home/timk/.local/lib/python3.8/site-packages/equinox/tree.py:120: FutureWarning: jax.tree_flatten is deprecated, and will be removed in a future release. Use jax.tree_util.tree_flatten instead.
#   leaves2, structure2 = jax.tree_flatten(node_or_nodes)
# norms 90.03622 45096.92
# norms 90.03622 45096.92
# working with W error
# searching for optimal lambda
# ->working with Bayesian Information Criterion
#  38%|███▊      | 76/200 [02:26<01:49,  1.14trial/s, best loss: -349.3484481555826]

# %% [markdown]
# Mixed norm

# %%
data = np.load("/data/cylin3dpod.npy")
print(data.shape) # data should have the shape (N_x,N_t)

# Instantiate the rebel class with the data.
# Adjust stepsize and evals if needed for faster testing.
model = rebel(data=data, stepsize=0.01, evals=200, error="mixed", order=2)

# Preprocess the data (calculate derivative and set up the library)
model.preprocess()

# (Optional) Calculate norms prior to optimization if you wish to inspect them separately.
model.calc_norms()

# Run the optimization procedure to estimate model parameters.
optimum, losses, errors = model.optimize()

# Print the optimization results.
print("Optimization optimum:", optimum)
print("Losses during optimization:", losses)
print("Errors:", errors)

# Plot the comparison of estimated vs. original trajectories.
model.plot_comparison()
